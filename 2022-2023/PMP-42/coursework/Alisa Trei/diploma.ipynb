# %%
# Install dependencies (cv2).

# ! pip install instagrapi
! pip install torch
! pip install torchvision
! pip install torchnet
! pip install keras
! pip install numpy
! pip install scipy
! pip install pillow
! pip install imageAI
! pip install opencv-python
! pip install tensorflow


# import instagrapi
# import tarfile
# import requests
# import csv
# import random
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.optim import lr_scheduler
# import numpy as np
# import torchvision
# from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
# import time
import os
import os.path
# import copy
# import seaborn as sn
# import pandas as pd
# import torchnet.meter.confusionmeter as cm
import shutil
import math
import PIL
import mpl_toolkits.axes_grid1 as grd
import cv2
import collections
from imageai.Detection import ObjectDetection
from imageai.Classification import ImageClassification
# Out:
# ...
#      |███████████████▉                | 307.1 MB 130.0 MB/s eta 0:00:03     |███████████                     | 211.5 MB 140.8 MB/s eta 0:00:03
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |███████████████████████████████▍| 608.7 MB 130.6 MB/s eta 0:00:01
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 619.9 MB 13 kB/s
# ...

# %%
# Install dependencies (ai).

# ! pip install instagrapi
! pip install torch
! pip install torchvision
! pip install torchnet
! pip install keras
! pip install numpy
! pip install scipy
! pip install pillow
! pip install imageAI
! pip install opencv-python
! pip install tensorflow


# import instagrapi
import tarfile
import requests
import csv
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import os.path
import copy
import seaborn as sn
import pandas as pd
import torchnet.meter.confusionmeter as cm
import shutil
import math
import PIL
# import mpl_toolkits.axes_grid1 as grd
import cv2
import collections
# from imageai.Detection import ObjectDetection
# from imageai.Classification import ImageClassification
# Out:
# ...
#      |████████████████                | 309.1 MB 126.5 MB/s eta 0:00:03
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |███████████████████████████████▋| 611.6 MB 126.5 MB/s eta 0:00:01
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |████████████████████████████████| 619.9 MB 9.3 kB/s
# ...
#      |████████████████████████████████| 168.4 MB 76 kB/s /s eta 0:00:01
# ...

# %%
s = """
77 passion flower 
73 water lily 
88 cyclamen 
89 watercress 
81 frangipani 
46 wallflower 
74 rose 
51 petunia 
44 poinsettia 
82 clematis 
83 hibiscus 
78 lotus 
80 anthurium 
75 thorn apple 
41 barbeton daisy 
43 sword lily 
76 morning glory 
84 columbine 
58 geranium 
56 bishop of llandaff 
86 tree mallow 
60 pink-yellow dahlia? 
92 bee balm 
11 snapdragon 
65 californian poppy 
8 bird of paradise 
23 fritillary 
30 sweet william 
72 azalea 
53 primula 
37 cape flower 
17 purple coneflower 
12 colt's foot 
29 artichoke 
52 wild pansy 
18 peruvian lily 
36 ruby-lipped cattleya 
90 canna lily 
71 gazania 
40 lenten rose
48 buttercup 
55 pelargonium 
85 desert-rose 
91 hippeastrum 
20 giant white arum lily 
47 marigold 
59 orange dahlia 
2 hard-leaved pocket orchid 
5 english marigold 
28 stemless gentian 
70 tree poppy 
22 pincushion flower 
54 sunflower 
87 magnolia 
66 osteospermum 
32 garden phlox 
4 sweet pea 
42 daffodil 
13 king protea 
38 great masterwort 
63 black-eyed susan 
68 bearded iris 
69 japanese anemone 
93 ball moss 
14 spear thistle 
64 silverbush 
19 balloon flower 
49 oxeye daisy 
61 cautleya spicata 
50 common dandelion 
15 yellow iris 
9 monkshood 
33 love in the mist 
26 corn poppy 
25 grape hyacinth 
3 canterbury bells 
16 globe-flower 
79 toad lily 
1 pink primrose 
21 fire lily 
24 red ginger 
27 prince of wales feathers flower 
31 carnation 
34 mexican aster 
35 alpine sea holly 
39 siam tulip 
67 spring crocus 
10 globe thistle 
45 bolero deep blue 
6 tiger lily 
7 moon orchid 
57 gaura 
62 windflower 
94 foxglove 
95 mexican petunia 
96 camellia 
97 mallow 
98 mexican petunia 
99 bromelia 
100 blanket flower 
101 trumpet creeper 
102 blackberry lily
"""
rows = s.split("\n")
matrix = [x for x in [[w for w in r.split(" ") if w != ""] for r in rows] if len(x) > 1]
labels = {
    int(matrix[i][0]): " ".join(matrix[i][1:])
    for i in range(len(matrix))
}
# Out:
# {77: 'passion flower',
#  73: 'water lily',
#  88: 'cyclamen',
#  89: 'watercress',
#  81: 'frangipani',
#  46: 'wallflower',
#  74: 'rose',
#  51: 'petunia',
#  44: 'poinsettia',
#  82: 'clematis',
#  83: 'hibiscus',
#  78: 'lotus',
#  80: 'anthurium',
#  75: 'thorn apple',
#  41: 'barbeton daisy',
#  43: 'sword lily',
#  76: 'morning glory',
#  84: 'columbine',
#  58: 'geranium',
#  56: 'bishop of llandaff',
#  86: 'tree mallow',
#  60: 'pink-yellow dahlia?',
#  92: 'bee balm',
#  11: 'snapdragon',
#  65: 'californian poppy',
#  8: 'bird of paradise',
#  23: 'fritillary',
#  30: 'sweet william',
#  72: 'azalea',
#  53: 'primula',
#  37: 'cape flower',
#  17: 'purple coneflower',
#  12: "colt's foot",
#  29: 'artichoke',
#  52: 'wild pansy',
#  18: 'peruvian lily',
#  36: 'ruby-lipped cattleya',
#  90: 'canna lily',
#  71: 'gazania',
#  40: 'lenten rose',
#  48: 'buttercup',
#  55: 'pelargonium',
#  85: 'desert-rose',
#  91: 'hippeastrum',
#  20: 'giant white arum lily',
# ...

# %%
# Log in to instagram API.

USERNAME = "flowers.searcher"
PASSWORD = "SDFvbn17!"
client = instagrapi.Client()
client.login(USERNAME, PASSWORD)

# %%
# Load media by 'flower' hashtag.

hashtag_media = client.hashtag_medias_a1(name="flower", amount=10000, tab_key="edge_hashtag_to_media")
# ...

# %%
# Import training dataset from Oxford (https://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html).

# source = "https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz"
# destination = source.split("/")[-1]
# response = requests.get(source)
# open(destination, "wb").write(response.content)
# with tarfile.open(destination) as archive:
#     archive.extractall()

# source = "https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat"
# destination = source.split("/")[-1]
# response = requests.get(source)
# open(destination, "wb").write(response.content)

with open("labels.csv") as labels_file:
    reader = csv.reader(labels_file, delimiter=",", quotechar="\"")
    labels = {row[0]: int(row[1]) for row in reader}
classes = dict()
for k, v in labels.items():
    if v not in classes.keys():
        classes[v] = list()
    classes[v].append(k)
classes[11]
    
ratio = {
    "val": 0.1,
    "test": 0.1,
}
for cls in classes.keys():
    files, count = classes[cls], len(classes[cls])
    offset_val = math.floor(count * ratio["val"])
    offset_test = offset_val + math.floor(count * ratio["test"])
    split = {
        "val": files[:offset_val],
        "test": files[offset_val:offset_test],
        "train": files[offset_test:],
    }
    for splt, files in split.items():
        destination = f"datasets/{splt}/{cls}"
        if not os.path.exists(f"datasets/{splt}"):
            os.mkdir(f"datasets/{splt}")
        os.mkdir(destination)
        for f in files:
            shutil.copy(f"jpg/{f}", destination)
# Out:
# ['image_03095.jpg',
#  'image_03096.jpg',
#  'image_03097.jpg',
#  'image_03098.jpg',
#  'image_03099.jpg',
#  'image_03100.jpg',
#  'image_03101.jpg',
#  'image_03102.jpg',
#  'image_03103.jpg',
#  'image_03104.jpg',
#  'image_03105.jpg',
#  'image_03106.jpg',
#  'image_03107.jpg',
#  'image_03108.jpg',
#  'image_03109.jpg',
#  'image_03110.jpg',
#  'image_03111.jpg',
#  'image_03112.jpg',
#  'image_03113.jpg',
#  'image_03114.jpg',
#  'image_03115.jpg',
#  'image_03116.jpg',
#  'image_03117.jpg',
#  'image_03118.jpg',
#  'image_03119.jpg',
#  'image_03120.jpg',
#  'image_03121.jpg',
#  'image_03122.jpg',
#  'image_03123.jpg',
#  'image_03124.jpg',
#  'image_03125.jpg',
#  'image_03126.jpg',
#  'image_03127.jpg',
#  'image_03128.jpg',
#  'image_03129.jpg',
#  'image_03130.jpg',
#  'image_03131.jpg',
#  'image_03132.jpg',
#  'image_03133.jpg',
#  'image_03134.jpg',
#  'image_03135.jpg',
#  'image_03136.jpg',
#  'image_03137.jpg',
#  'image_03138.jpg',
#  'image_03139.jpg',
# ...

# %%
# Data augmentation and normalization for training.
# Just normalization for validation & test.

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %%
data_dir = 'datasets'
image_datasets = {
    x: datasets.ImageFolder(
        os.path.join(data_dir, x), 
        data_transforms[x]
    ) 
    for x in data_transforms.keys()}
dataloaders = {
    x: torch.utils.data.DataLoader(
        image_datasets[x], batch_size=16,
        shuffle=True, num_workers=4
    ) 
    for x in data_transforms.keys()
}
dataset_sizes = {x: len(image_datasets[x]) for x in data_transforms.keys()}
class_names = image_datasets['train'].classes
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Lists for graph generation.

epoch_counter_train = []
epoch_counter_val = []
train_loss = []
val_loss = []
train_acc = []
val_acc = []

# %%
# check shape (to delete later)
examples = next(iter(dataloaders["train"]))

for label, img  in enumerate(examples):
    print(img.shape)
# Out:
# torch.Size([16, 3, 224, 224])
# torch.Size([16])

# %%
# Train the model.

def train_model(model, criterion, optimizer, scheduler, num_epochs):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch + 1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase.
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  # Set model to training mode.
            else:
                model.eval()   # Set model to evaluate mode.

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Zero the parameter gradients.
                optimizer.zero_grad()

                # Forward + track history if only in train.
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Backward + optimize only if in training phase.
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics.
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            # For graph generation.
            if phase == "train":
                train_loss.append(running_loss/dataset_sizes[phase])
                train_acc.append(running_corrects.double() / dataset_sizes[phase])
                epoch_counter_train.append(epoch)
            if phase == "val":
                val_loss.append(running_loss/ dataset_sizes[phase])
                val_acc.append(running_corrects.double() / dataset_sizes[phase])
                epoch_counter_val.append(epoch)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            # For printing.       
            if phase == "train":    
                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]
            if phase == "val":    
                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # Deep copy the best model.
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # Load best model weights.
    model.load_state_dict(best_model_wts)
    return model

# %%
# Using a model pre-trained on ImageNet and replacing it's final linear layer.

# For resnet18.
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 102)
model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()

# Using Adam as the parameter optimizer.
optimizer_ft = optim.Adam(model_ft.parameters(), lr = 0.001, betas=(0.9, 0.999))

# Decay LR by a factor of 0.1 every 7 epochs.
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)       
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=25)
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/jovyan/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 368MB/s]
# Epoch 1/25
# ----------
# ...

# %%
torch.save(model_ft, "./model.sav")

# %%
model_ft = torch.load("./model.sav")

# %%
# Plot the train & validation losses.

plt.figure(1)
plt.title("Training Vs Validation Losses")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(epoch_counter_train,train_loss,color = 'r', label="Training Loss")
plt.plot(epoch_counter_val,val_loss,color = 'g', label="Validation Loss")
plt.legend()
plt.show()

# Plot the accuracies in train & validation.

plt.figure(2)
plt.title("Training Vs Validation Accuracies")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(epoch_counter_train,train_acc,color = 'r', label="Training Accuracy")
plt.plot(epoch_counter_val,val_acc,color = 'g', label="Validation Accuracy")
plt.legend()
plt.show()

# %%
# Test the accuracy with test data.

correct = 0
total = 0
with torch.no_grad():
    for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model_ft(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the test images: 94 %

# %%
# Class wise testing accuracy.

class_correct = list(0. for i in range(102))
class_total = list(0. for i in range(102))
with torch.no_grad():
    for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model_ft(inputs)
            _, predicted = torch.max(outputs, 1)
            point = (predicted == labels).squeeze()
            for j in range(len(labels)):
                label = labels[j]
                class_correct[label] += point[j].item()
                class_total[label] += 1

for i in range(8):
    print('Accuracy of %5s : %2d %%' % (class_names[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of     1 : 100 %
# Accuracy of    10 : 100 %
# Accuracy of   100 : 100 %
# Accuracy of   101 : 100 %
# Accuracy of   102 : 100 %
# Accuracy of    11 : 100 %
# Accuracy of    12 : 100 %
# Accuracy of    13 : 100 %

# %%
# Get the confusion matrix for testing data.

confusion_matrix = cm.ConfusionMeter(102)
with torch.no_grad():
    for i, (inputs, labels) in enumerate(dataloaders['test']):
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model_ft(inputs)
        _, predicted = torch.max(outputs, 1)
        confusion_matrix.add(predicted, labels)
    print(confusion_matrix.conf)

# Confusion matrix as a heatmap.
con_m = confusion_matrix.conf
df_con_m = pd.DataFrame(con_m, index= [i for i in class_names], columns = [i for i in class_names])
sn.set(font_scale= 1.1)
sn.heatmap(df_con_m, annot=True,fmt='g', annot_kws={"size" : 1}, cbar = False, cmap="Blues")
# Out:
# [[4 0 0 ... 0 0 0]
#  [0 4 0 ... 0 0 0]
#  [0 0 4 ... 0 0 0]
#  ...
#  [0 0 0 ... 4 0 0]
#  [0 0 0 ... 0 8 0]
#  [0 0 0 ... 0 0 5]]
# <AxesSubplot:>

# %%
sample_source = "./sample/in"
sample_destination = "./sample/out"
source_image_names = os.listdir(sample_source)

# %%
source_images = [PIL.Image.open(os.path.join(sample_source, n)) for n in source_image_names if not n.startswith(".")]
fig = plt.figure(figsize=(12., 12.))
grid = grd.ImageGrid(
    fig, 111,
    nrows_ncols=(3, 3),
    axes_pad=0.1,
)
for ax, im in zip(grid, source_images):
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.imshow(im)
plt.show()

# %%
obj_detect = ObjectDetection()

obj_detect.setModelTypeAsYOLOv3()
obj_detect.setModelPath("./yolov3.pt")

# obj_detect.setModelTypeAsRetinaNet()
# obj_detect.setModelPath("./retinanet_resnet50_fpn_coco-eeacb38b.pth")

obj_detect.loadModel()

# %%
for p in source_image_names:
    print(f"{p}:")
    src, dst = os.path.join(sample_source, p), os.path.join(sample_destination, p)
    detected_obj = obj_detect.detectObjectsFromImage(
        input_image=src,
        output_image_path=dst
    )
    if len(detected_obj) == 0:
        shutil.copyfile(src, dst)
    for obj in detected_obj:
        print("\t" + obj["name"] + "-"
              + str(obj["percentage_probability"]),
              obj["box_points"])
    print()
# Out:
# 1.jpg :
#       flower-97.88 [10, 15, 188, 191]
#
# 9.jpg :
#       flower-99.74 [18, 10, 195, 178]
#
# 5.jpg :
#       cup-95.16 [12, 32, 187, 176]
#
# 3.jpg :
#       clothes-94.55 [5, 3, 191, 194]
#
# 7.jpg :
#       flower-93.66 [14, 60, 69, 125]
#       flower-94.51 [74, 34, 157, 150]
#       flower-95.42 [159, 6, 199, 55]
#
# 2.jpg :
#       apple-99.51 [34, 8, 108, 78]
#       apple-99.71 [79, 66, 143, 123]
#       apple-98.16 [7, 70, 75, 152]
#       apple-99.46 [43, 105, 109, 172]
#       apple-99.79 [111, 85, 191, 166]
#
# 6.jpg :
#       flower-92.82 [4, 24, 193, 174]
#
# 4.jpg :
#       plate-99.70 [14, 39, 132, 164]
#       plate-97.53 [102, 34, 182, 157]
#
# 8.jpg :
#       flower-93.68 [1, 45, 48, 109]
#       flower-93.57 [75, 21, 154, 80]
#       flower-96.77 [16, 86, 93, 149]
#       flower-93.69 [84, 88, 141, 152]
#       flower-92.56 [164, 30, 199, 106]
#       flower-94.83 [160, 130, 197, 199]

# %%
destiantion_images = [PIL.Image.open(os.path.join(sample_destination, n)) for n in os.listdir(sample_destination) if not n.startswith(".")]
fig = plt.figure(figsize=(12., 12.))
grid = grd.ImageGrid(
    fig, 111,
    nrows_ncols=(3, 3),
    axes_pad=0.1,
)
for ax, im in zip(grid, destiantion_images):
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.imshow(im)
plt.show()

# %%
import mpl_toolkits.axes_grid1 as grd
import random
sample_source = "./instagram"
source_image_names = random.sample(os.listdir(sample_source), 9)
source_images = [PIL.Image.open(os.path.join(sample_source, n)) for n in source_image_names if not n.startswith(".")]
fig = plt.figure(figsize=(12., 12.))
grid = grd.ImageGrid(
    fig, 111,
    nrows_ncols=(3, 3),
    axes_pad=0.1,
)
for ax, im in zip(grid, source_images):
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.imshow(im)
plt.show()

# %%
# real
def is_flower(src: str) -> bool:
    detected_obj = obj_detect.detectObjectsFromImage(
        input_image=src
    )
    if len(detected_obj) == 0:
        return False
    for obj in detected_obj:
        if obj["name"] == "flower":
            return True
        return False

# %%
import torch
import json
from torchvision import transforms
from PIL import Image
flowers, non_flowers = 0, 0
src = "./instagram"
softmax = nn.Softmax(dim=1)
convert_tensor = transforms.ToTensor()
counters = dict()
for y in [os.path.join(src, x) for x in os.listdir(src)]:
    if is_flower(y):
        flowers += 1
        img = Image.open(y)
        tensor = convert_tensor(img)
        result = model_ft(tensor.unsqueeze(0))
        probabilities = softmax(result).tolist()[0]
        i = probabilities.index(max(probabilities))
        label = labels[i+1]
        if label not in counters.keys():
            counters[label] = 0
        counters[label] += 1
    else:
        non_flowers += 1
print(f"flowers: {flowers}")
print(f"non-flowers: {non_flowers}")
with open("./counters.json", "w") as f:
    json.dump(counters, f)
# Out:
# flowers: 6639
# non-flowers: 390

# %%
counters
# Out:
# {'californian poppy': 166,
#  'globe-flower': 531,
#  'morning glory': 1899,
#  'canna lily': 1103,
#  'toad lily': 445,
#  'artichoke': 13,
#  'siam tulip': 260,
#  'barbeton daisy': 611,
#  'common dandelion': 81,
#  'mexican aster': 135,
#  'petunia': 4,
#  'moon orchid': 27,
#  'mallow': 54,
#  'gazania': 41,
#  'foxglove': 85,
#  'mexican petunia': 66,
#  'clematis': 29,
#  'watercress': 16,
#  'passion flower': 81,
#  'stemless gentian': 110,
#  'carnation': 18,
#  'hard-leaved pocket orchid': 11,
#  'silverbush': 106,
#  'thorn apple': 155,
#  'pelargonium': 58,
#  'oxeye daisy': 19,
#  'lenten rose': 44,
#  "colt's foot": 9,
#  'balloon flower': 29,
#  'cape flower': 31,
#  'monkshood': 14,
#  'pink primrose': 6,
#  'daffodil': 18,
#  'tree poppy': 2,
#  'cyclamen': 18,
#  'desert-rose': 8,
#  'water lily': 34,
#  'snapdragon': 14,
#  'alpine sea holly': 37,
#  'trumpet creeper': 3,
#  'black-eyed susan': 27,
#  'love in the mist': 1,
#  'english marigold': 2,
# ...

# %%
import matplotlib.pyplot as plt

plt.figure().set_figwidth(15)
plt.bar(range(len(counters)), list(counters.values()), align='center')
plt.xticks(range(len(counters)), list(counters.keys()))
plt.xticks(rotation=90, ha='right')

plt.show()
